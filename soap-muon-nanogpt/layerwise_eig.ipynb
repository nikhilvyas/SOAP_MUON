# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

Z = 2
L = 5
bsz = 1000

g = torch.ones(bsz, L*Z)+.1*torch.randn(bsz, L*Z)

g[:, :2] *= .1


H = g.T @ g
# Out:
# tensor(0.0044)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

g = torch.ones(10)
g[0] = .1

H = g[:, None] @ g[None, :]
